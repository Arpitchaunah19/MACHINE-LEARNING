# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Arpit\\Downloads\\house_price_data.csv")

# %%
import pandas as pd
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/datablist/sample-csv-files/main/files/people/people-100.csv"  # example raw CSV
headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(url, headers=headers)

data = StringIO(response.text)
df = pd.read_csv(data)
print(df.head())
# Out:
# Empty DataFrame
# Columns: [404: Not Found]
# Index: []

# %%
# pd.read_csv('n,sdjkdak/sds.tsv',sep='\t' , name=['s.no', to add header])

# %%
df = pd.read_csv("C:\\Users\\Arpit\\Downloads\\house_price_data.csv",index_col='location_type')
df.head()
# Out:
#                area_sqft  bedrooms  bathrooms  property_age  \
# location_type
# Rural               1736         3          2            13
# Urban               2453         2          2            25
# Rural               2120         2          1            12
# Rural               1163         1          1            26
# Urban               1891         1          1             8
#
#                distance_main_road  view_rating  has_parking  locality_rating  \
# location_type
# Rural                        2.12            6            1              7.1
# Urban                        1.81            9            0              7.1
# Rural                        4.65            2            1              7.1
# Rural                        4.17            5            0              7.1
# Urban                        4.83            3            1              7.1
#
#                price_lakhs
# location_type
# Rural                99.92
# Urban               107.55
# ...

# %%
# header parameter 
#pd.read_csv("test.csv",header=1)

# %%
import pandas as pd
df = pd.read_json("C:\\Users\\Arpit\\Downloads\\baking.json.zip")

# %%
df
# Out:
#                                        id  \
# 0    16a94310-cea8-435f-90e8-10f8b02b7bfe
# 1    5edaf257-7a3b-4878-bf3c-99922f319e7a
# 2    aa999c11-f8c0-40c5-8239-732339e3cd57
# 3    5d49a07d-cc45-492e-bb66-0db776dc2c2b
# 4    30f735f0-cbfe-4884-bc8c-25e0472fb156
# ..                                    ...
# 609  ee4c477e-e315-41c6-b08e-7cb7fe76b607
# 610  4f8657aa-4d56-42d5-a0f4-51bd3c7875b1
# 611  5b78eb57-481a-4b12-9c14-40d9311524f7
# 612  fb1c1ec1-a65a-441e-ab6f-33fe7b32dfde
# 613  966271b5-2e13-4d5b-b214-b31b9e733f40
#
#                                                    url  \
# 0    https://www.bbcgoodfood.com/recipes/easy-bread...
# 1      https://www.bbcgoodfood.com/recipes/pizza-rolls
# 2    https://www.bbcgoodfood.com/recipes/foccaccia-...
# 3    https://www.bbcgoodfood.com/recipes/cheesy-sau...
# 4    https://www.bbcgoodfood.com/recipes/ploughmans...
# ..                                                 ...
# 609  https://www.bbcgoodfood.com/recipes/raw-lemon-...
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
